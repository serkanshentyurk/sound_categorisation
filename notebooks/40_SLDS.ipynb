# %% [markdown]
# # 5. SLDS Learning Phase Assignment
#
# **Purpose**: Discover behavioural regimes (learning phases) from session-level
# statistics, blind to session labels. Provides principled, real-time state
# definitions for triggering opto experiments (Aim 2) and tracking neural
# dynamics (Aim 3).
#
# **Approach** (progressive):
# 1. HMM — discrete states only (baseline)
# 2. SLDS — discrete states × continuous dynamics (full model)
#
# Both fitted via `ssm` (Linderman lab). Model selection by BIC over:
# - K (number of discrete states)
# - D (latent dimensionality, SLDS only)
#
# **Expected states**:
# - "Learning": high recency, low accuracy, unstable PSE, high choice entropy
# - "Expert": low recency, high accuracy, stable PSE, low choice entropy
# - Possibly: "Transition" / "Post-shift" states
#
# **Validation**:
# - Terminal expert state should look similar across animals
# - SLDS states should correlate with model-based measures (η from SBI)
# - Number of states by BIC, not imposed a priori
#
# **Features from 1a**: accuracy, pse, slope, recency, choice_entropy,
# win_stay, side_bias, lapse_low
#
# ```bash
# pip install ssm  # git+https://github.com/lindermanlab/ssm
# ```

# %%
# %matplotlib inline
from shared_setup import *

import matplotlib.colors as mcolors
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
from behav_utils.analysis.session_features import (
    build_feature_matrix, build_feature_matrix_multi, get_feature_columns,
)
from behav_utils.plotting.styles import COLOURS, apply_style

apply_style()
print('Core imports OK')
# Out:
# Core imports OK

# %%
import ssm

# %% [markdown]
# ## 1. Configuration

# %%
CONFIG_PATH = Path('../config.yaml')
STAGE = 'Full_Task_Cont'
MIN_SESSIONS = 10

# Features from notebook 1a
SELECTED_FEATURES = [
    'accuracy', 'pse', 'slope', 'recency',
    'choice_entropy', 'win_stay', 'side_bias', 'lapse_low',
]

# Model comparison ranges
K_RANGE = range(2, 10)       # discrete states: 2–9
D_LATENT_RANGE = [1, 2, 3, 4, 5, 6, 7, 8, 9]  # SLDS latent dims

N_HMM_RESTARTS = 10  # EM is sensitive to initialisation
SEED = 42

# %% [markdown]
# ## 2. Load Data & Build Feature Matrix

# %%
experiment, load_info = load_data()
all_animals = experiment.get_animals(min_sessions=MIN_SESSIONS, stage=STAGE)
print(f'{len(all_animals)} animals with >= {MIN_SESSIONS} sessions')

# Build multi-animal feature matrix
df = build_feature_matrix_multi(
    all_animals, stage=STAGE,
    stat_names=['accuracy', 'psychometric', 'recency', 'choice_entropy',
                'win_stay', 'side_bias'],
)
print(f'Feature matrix: {len(df)} sessions × {len(df.columns)} columns')
print(f'Animals: {df["animal_id"].nunique()}')
# Out:
# Loaded snapshot: 22 animals, 885 sessions (exported 2026-04-25)
# 21 animals with >= 10 sessions
# Feature matrix: 762 sessions × 33 columns
# Animals: 21

# %%
# Check which selected features are available
available = [f for f in SELECTED_FEATURES if f in df.columns]
missing = [f for f in SELECTED_FEATURES if f not in df.columns]
if missing:
    print(f'Missing features: {missing}')
    print(f'Available columns: {sorted(df.columns.tolist())}')
print(f'Using {len(available)} features: {available}')

FEATURES = available
# Out:
# Using 8 features: ['accuracy', 'pse', 'slope', 'recency', 'choice_entropy', 'win_stay', 'side_bias', 'lapse_low']

# %%
# NaN audit
for f in FEATURES:
    n_nan = df[f].isna().sum()
    pct = 100 * n_nan / len(df)
    print(f'  {f:>20s}: {n_nan:>4d} NaN ({pct:.1f}%)')

# Drop sessions with any NaN in selected features
df_clean = df.dropna(subset=FEATURES).copy()
print(f'\nAfter dropping NaN: {len(df_clean)} sessions '
      f'(dropped {len(df) - len(df_clean)})')
# Out:
#               accuracy:    0 NaN (0.0%)
#                    pse:   63 NaN (8.3%)
#                  slope:   63 NaN (8.3%)
#                recency:    0 NaN (0.0%)
#         choice_entropy:    0 NaN (0.0%)
#               win_stay:    0 NaN (0.0%)
#              side_bias:    0 NaN (0.0%)
#              lapse_low:    0 NaN (0.0%)
#
# After dropping NaN: 699 sessions (dropped 63)

# %%
# Standardise features (zero mean, unit variance) across all animals
scaler = StandardScaler()
X_all = scaler.fit_transform(df_clean[FEATURES].values)
print(f'Standardised feature matrix: {X_all.shape}')

# Split into per-animal sequences (preserving temporal order)
animal_ids = df_clean['animal_id'].unique()
animal_sequences = {}  # animal_id -> (X, session_indices)

for aid in animal_ids:
    mask = df_clean['animal_id'] == aid
    X_animal = X_all[mask.values]
    sess_idx = df_clean.loc[mask, 'session_idx'].values
    animal_sequences[aid] = (X_animal, sess_idx)
    print(f'  {aid}: {X_animal.shape[0]} sessions')

# Prepare data formats for ssm
X_list = [seq[0] for seq in animal_sequences.values()]
X_concat = np.concatenate(X_list)
n_total_obs = X_concat.shape[0]
D_obs = len(FEATURES)
print(f'\nTotal observations: {n_total_obs}, D_obs: {D_obs}')
# Out:
# Standardised feature matrix: (699, 8)
#   SS01: 49 sessions
#   SS04: 76 sessions
#   SS05: 56 sessions
#   SS06: 61 sessions
#   SS07: 59 sessions
#   SS08: 60 sessions
#   SS09: 50 sessions
#   SS10: 40 sessions
#   SS11: 51 sessions
#   SS12: 13 sessions
#   SS13: 50 sessions
#   SS14: 14 sessions
#   SS15: 14 sessions
#   SS16: 15 sessions
#   SS17: 10 sessions
#   SS18: 15 sessions
#   SS19: 10 sessions
#   SS20: 15 sessions
#   SS21: 15 sessions
#   SS22: 13 sessions
#   SS23: 13 sessions
#
# Total observations: 699, D_obs: 8

# %% [markdown]
# ## 3. Parameter Counting & BIC
#
# Neither ssm HMM nor SLDS expose a built-in BIC. We count parameters
# manually and compute BIC = −2·LL + n_params·ln(n_obs).
#
# **Note on SLDS log-likelihood:** `model.log_likelihood()` computes an
# approximate marginal likelihood (exact for discrete states, approximate
# for continuous latent via Laplace). The approximation error is consistent
# across models so relative BIC comparisons remain valid.

# %%
def hmm_n_params(K: int, D: int) -> int:
    """Free parameters in ssm Gaussian-emission HMM."""
    init = K - 1                    # initial state simplex
    trans = K * (K - 1)             # transition rows (each a simplex)
    means = K * D                   # emission means
    covariances = K * D * (D + 1) // 2  # emission covariances (symmetric)
    return init + trans + means + covariances


def slds_n_params(K: int, D: int, N: int) -> int:
    """Free parameters in ssm Gaussian-emission SLDS.
    
    K: discrete states, D: latent dim, N: observation dim.
    """
    init = K - 1
    trans = K * (K - 1)
    dynamics = K * (D * D + D)              # A_k matrices + bias
    dynamics_cov = K * D * (D + 1) // 2
    emissions = K * (N * D + N)             # C_k matrices + bias
    emission_cov = K * N * (N + 1) // 2
    return init + trans + dynamics + dynamics_cov + emissions + emission_cov


def compute_bic(ll: float, n_params: int, n_obs: int) -> float:
    """BIC = -2*LL + n_params*ln(n_obs). Lower is better."""
    return -2 * ll + n_params * np.log(n_obs)


# Quick sanity check
print(f'HMM K=3, D={D_obs}: {hmm_n_params(3, D_obs)} params')
print(f'SLDS K=3, D=2, N={D_obs}: {slds_n_params(3, 2, D_obs)} params')
# Out:
# HMM K=3, D=8: 140 params
# SLDS K=3, D=2, N=8: 215 params

# %% [markdown]
# ## 4. HMM — Discrete States
#
# Gaussian HMM discovers discrete behavioural regimes without modelling
# within-state dynamics. Pooled model (shared emission parameters, each
# animal is a separate sequence). Multiple EM restarts per K.

# %%
hmm_scores = {}  # K -> {ll, bic, aic, n_params, model}

for K in K_RANGE:
    best_ll = -np.inf
    best_model = None

    for restart in range(N_HMM_RESTARTS):
        model = ssm.HMM(K, D_obs, observations='gaussian')
        try:
            model.fit(X_concat, method='em', num_iters=200)
            ll = model.log_likelihood(X_concat)
            if ll > best_ll:
                best_ll = ll
                best_model = model
        except Exception:
            continue

    if best_model is not None:
        n_p = hmm_n_params(K, D_obs)
        bic = compute_bic(best_ll, n_p, n_total_obs)
        aic = -2 * best_ll + 2 * n_p
        hmm_scores[K] = {
            'll': best_ll, 'bic': bic, 'aic': aic,
            'n_params': n_p, 'model': best_model,
        }
        print(f'  K={K}: LL={best_ll:.1f}, BIC={bic:.1f}, AIC={aic:.1f} (n_params={n_p})')

if hmm_scores:
    best_K_bic = min(hmm_scores, key=lambda k: hmm_scores[k]['bic'])
    best_K_aic = min(hmm_scores, key=lambda k: hmm_scores[k]['aic'])
    print(f'\nBest K: BIC → {best_K_bic}, AIC → {best_K_aic}')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   K=2: LL=-5011.4, BIC=10618.8, AIC=10204.8 (n_params=91)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   K=3: LL=-4513.2, BIC=9943.3, AIC=9306.4 (n_params=140)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   K=4: LL=-4154.3, BIC=9559.7, AIC=8690.7 (n_params=191)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   K=5: LL=-3921.9, BIC=9441.9, AIC=8331.8 (n_params=244)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   K=6: LL=-3736.7, BIC=9431.7, AIC=8071.4 (n_params=299)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   K=7: LL=-3654.6, BIC=9640.8, AIC=8021.1 (n_params=356)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   K=8: LL=-3514.6, BIC=9747.3, AIC=7859.2 (n_params=415)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   K=9: LL=-3385.7, BIC=9889.0, AIC=7723.3 (n_params=476)
#
# Best K: BIC → 6, AIC → 9

# %%
# Plot model comparison
if hmm_scores:
    fig, axes = plt.subplots(1, 2, figsize=(10, 4))
    ks = sorted(hmm_scores.keys())

    ax = axes[0]
    ax.plot(ks, [hmm_scores[k]['ll'] for k in ks], 'o-', color='navy')
    ax.set_xlabel('Number of states (K)')
    ax.set_ylabel('Log-likelihood')
    ax.set_title('HMM: Log-likelihood')

    ax = axes[1]
    ax.plot(ks, [hmm_scores[k]['bic'] for k in ks], 'o-', color='crimson', label='BIC')
    ax.plot(ks, [hmm_scores[k]['aic'] for k in ks], 's--', color='darkorange', label='AIC')
    ax.set_ylabel('Information criterion (lower = better)')
    ax.legend()
    ax.set_xlabel('Number of states (K)')
    ax.set_title('HMM: Model selection')

    fig.suptitle('HMM State Count Selection', fontsize=13, fontweight='bold')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 4b. HMM State Interpretation

# %%
if hmm_scores:
    K_best = best_K_bic
    hmm_best = hmm_scores[K_best]['model']
    print(f'Using K={K_best}')

    # Decode per animal
    hmm_labels = {}
    for aid, (X_a, sess_idx) in animal_sequences.items():
        hmm_labels[aid] = hmm_best.most_likely_states(X_a)

    # State means in original (unstandardised) feature space
    # ssm Gaussian observations: params is list of (mean, cov) per state
    state_means_std = hmm_best.observations.mus

    state_means = scaler.inverse_transform(state_means_std)

    print(f'\nState means (original scale):')
    means_df = pd.DataFrame(state_means, columns=FEATURES,
                             index=[f'State {k}' for k in range(K_best)])
    print(means_df.round(3).to_string())
# Out:
# Using K=6
#
# State means (original scale):
#          accuracy    pse  slope  recency  choice_entropy  win_stay  side_bias  lapse_low
# State 0     0.614  0.142  0.397    0.374           0.923     0.250      0.007      0.320
# State 1     0.709  0.223  0.451    0.108           0.730     0.045     -0.080      0.097
# State 2     0.602  0.484  0.461    0.084           0.594    -0.027     -0.280      0.051
# State 3     0.750  0.064  0.339    0.154           0.688     0.062      0.041      0.212
# State 4     0.803  0.086  0.326    0.023           0.559     0.013     -0.029      0.052
# State 5     0.565 -0.177  1.308    0.247           0.859     0.121     -0.009      0.138

# %%
# Heuristic labelling: which state is "expert"?
if hmm_scores:
    acc_col = FEATURES.index('accuracy')
    expert_state = np.argmax(state_means[:, acc_col])
    learning_state = np.argmin(state_means[:, acc_col])
    print(f'Highest accuracy: State {expert_state} '
          f'(acc={state_means[expert_state, acc_col]:.3f})')
    print(f'Lowest accuracy:  State {learning_state} '
          f'(acc={state_means[learning_state, acc_col]:.3f})')

    STATE_NAMES = {}
    STATE_NAMES[expert_state] = 'Expert'
    STATE_NAMES[learning_state] = 'Learning'
    for k in range(K_best):
        if k not in STATE_NAMES:
            STATE_NAMES[k] = f'Intermediate_{k}'

    print(f'\nState labels: {STATE_NAMES}')
# Out:
# Highest accuracy: State 4 (acc=0.803)
# Lowest accuracy:  State 5 (acc=0.565)
#
# State labels: {np.int64(4): 'Expert', np.int64(5): 'Learning', 0: 'Intermediate_0', 1: 'Intermediate_1', 2: 'Intermediate_2', 3: 'Intermediate_3'}

# %%
max_n = 0
n_animals = len(hmm_labels)
for aid, labels in hmm_labels.items():
    n = len(labels)
    if n > max_n:
        max_n = n

# %%
hmm_labels_arr = np.nan * np.empty((n_animals, max_n), dtype=int)
for i, (aid, labels) in enumerate(hmm_labels.items()):
	n = len(labels)
	hmm_labels_arr[i, :n] = labels

# %%
plt.imshow(hmm_labels_arr[:,:50], aspect='auto', cmap='tab20', vmin=-0.5, vmax=K_best-0.5)
plt.ylabel('Animal')
plt.yticks(ticks=range(n_animals), labels=list(hmm_labels.keys()), fontsize=8)
plt.xlabel('Session')
plt.title('HMM State Assignments per Session')
# Out:
# Text(0.5, 1.0, 'HMM State Assignments per Session')

# %%
# Plot state trajectories per animal
if hmm_scores:
    state_colours = plt.cm.Set2(np.linspace(0, 1, K_best))

    n_animals = len(animal_sequences)
    fig, axes = plt.subplots(n_animals, 1,
                              figsize=(14, 2.5 * n_animals),
                              sharex=False)
    if n_animals == 1:
        axes = [axes]

    for ax, (aid, (X_a, sess_idx)) in zip(axes, animal_sequences.items()):
        labels = hmm_labels[aid]

        for k in range(K_best):
            mask = labels == k
            ax.scatter(sess_idx[mask], np.ones(mask.sum()) * 0.5,
                       c=[state_colours[k]], s=80, marker='s',
                       label=STATE_NAMES.get(k, f'S{k}'))

        # Overlay accuracy trajectory
        acc_idx = FEATURES.index('accuracy')
        acc_orig = scaler.inverse_transform(X_a)[:, acc_idx]
        ax2 = ax.twinx()
        ax2.plot(sess_idx, acc_orig, '-', color='grey', alpha=0.5, lw=1)
        ax2.set_ylabel('Accuracy', fontsize=8, color='grey')

        ax.set_ylabel(aid, fontsize=9, fontweight='bold')
        ax.set_yticks([])
        if ax == axes[0]:
            ax.legend(fontsize=7, loc='upper right', ncol=K_best)

    axes[-1].set_xlabel('Session index')
    fig.suptitle(f'HMM State Assignments (K={K_best})',
                 fontsize=13, fontweight='bold')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 4c. HMM Transition Matrix

# %%
if hmm_scores:
    trans = np.exp(hmm_best.transitions.log_Ps)

    fig, ax = plt.subplots(figsize=(5, 4))
    im = ax.imshow(trans, cmap='Blues', vmin=0, vmax=1)
    for i in range(K_best):
        for j in range(K_best):
            ax.text(j, i, f'{trans[i, j]:.2f}', ha='center', va='center',
                    fontsize=9, color='white' if trans[i, j] > 0.5 else 'black')
    labels = [STATE_NAMES.get(k, f'S{k}') for k in range(K_best)]
    ax.set_xticks(range(K_best))
    ax.set_xticklabels(labels, fontsize=9, rotation=45, ha='right')
    ax.set_yticks(range(K_best))
    ax.set_yticklabels(labels, fontsize=9)
    ax.set_xlabel('To')
    ax.set_ylabel('From')
    ax.set_title(f'HMM Transition Matrix (K={K_best})')
    plt.colorbar(im, ax=ax, label='P(transition)')
    plt.tight_layout()
    plt.show()

    print('\nKey transitions:')
    for i in range(K_best):
        for j in range(K_best):
            if i != j and trans[i, j] > 0.05:
                print(f'  {STATE_NAMES.get(i, f"S{i}")} → '
                      f'{STATE_NAMES.get(j, f"S{j}")}: {trans[i, j]:.3f}')
# Out:
# Key transitions:
#   Intermediate_0 → Intermediate_3: 0.061
#   Intermediate_0 → Learning: 0.189
#   Intermediate_1 → Intermediate_2: 0.055
#   Intermediate_1 → Intermediate_3: 0.092
#   Intermediate_2 → Intermediate_1: 0.214
#   Intermediate_3 → Intermediate_1: 0.187
#   Intermediate_3 → Expert: 0.100
#   Learning → Intermediate_0: 0.392
#   Learning → Intermediate_1: 0.079
#   Learning → Intermediate_3: 0.104

# %% [markdown]
# ## 5. SLDS — Switching Linear Dynamical System
#
# Extends HMM with continuous latent dynamics within each discrete state.
# Grid search over K (discrete states) and D (latent dimensionality),
# selected by BIC.

# %%
slds_results = {}  # (K, D) -> {ll, bic, n_params, model, elbos}

for K in K_RANGE:
    for D in D_LATENT_RANGE:
        key = (K, D)
        print(f'SLDS K={K}, D={D}... ', end='', flush=True)

        model = ssm.SLDS(
            N=D_obs, K=K, D=D,
            emissions='gaussian',
            dynamics='gaussian',
        )

        try:
            elbos = model.fit(
                X_list, method='laplace_em',
                num_iters=100, initialize=True,
            )
            ll = model.log_likelihood(X_list)
            n_p = slds_n_params(K, D, D_obs)
            bic = compute_bic(ll, n_p, n_total_obs)

            slds_results[key] = {
                'll': ll, 'bic': bic,
                'n_params': n_p, 'model': model,
                'elbos': elbos,
            }
            print(f'LL={ll:.1f}  BIC={bic:.1f}  (n_params={n_p})')

        except Exception as e:
            print(f'Failed: {e}')

if slds_results:
    best_slds_key = min(slds_results, key=lambda k: slds_results[k]['bic'])
    best_K_slds, best_D_slds = best_slds_key
    print(f'\nBest SLDS by BIC: K={best_K_slds}, D={best_D_slds}')
    print(f'  BIC={slds_results[best_slds_key]["bic"]:.1f}, '
          f'LL={slds_results[best_slds_key]["ll"]:.1f}, '
          f'n_params={slds_results[best_slds_key]["n_params"]}')
else:
    print('No SLDS models fitted successfully.')
    best_K_slds, best_D_slds = None, None
# Out:
# SLDS K=2, D=1...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=2, D=2...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=2, D=3...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=2, D=4...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=2, D=5...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=2, D=6...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=2, D=7...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=2, D=8...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed:
# SLDS K=2, D=9... Failed: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 8 is different from 9)
# SLDS K=3, D=1...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=3, D=2...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=3, D=3...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=3, D=4...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=3, D=5...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=3, D=6...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=3, D=7...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=3, D=8...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed:
# SLDS K=3, D=9... Failed: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 8 is different from 9)
# SLDS K=4, D=1...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=4, D=2...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=4, D=3...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=4, D=4...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=4, D=5...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=4, D=6...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=4, D=7...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=4, D=8...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed:
# SLDS K=4, D=9... Failed: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 8 is different from 9)
# SLDS K=5, D=1...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=5, D=2...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=5, D=3...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=5, D=4...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=5, D=5...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=5, D=6...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=5, D=7...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=5, D=8...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed:
# SLDS K=5, D=9... Failed: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 8 is different from 9)
# SLDS K=6, D=1...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=6, D=2...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=6, D=3...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=6, D=4...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=6, D=5...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=6, D=6...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=6, D=7...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=6, D=8...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed:
# SLDS K=6, D=9... Failed: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 8 is different from 9)
# SLDS K=7, D=1...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=7, D=2...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=7, D=3...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=7, D=4...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=7, D=5...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=7, D=6...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=7, D=7...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=7, D=8...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed:
# SLDS K=7, D=9... Failed: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 8 is different from 9)
# SLDS K=8, D=1...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=8, D=2...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=8, D=3...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=8, D=4...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=8, D=5...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=8, D=6...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=8, D=7...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=8, D=8...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed:
# SLDS K=8, D=9... Failed: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 8 is different from 9)
# SLDS K=9, D=1...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=9, D=2...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=9, D=3...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=9, D=4...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=9, D=5...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=9, D=6...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=9, D=7...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed: 'SLDS' object has no attribute 'log_likelihood'
# SLDS K=9, D=8...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initializing with an ARHMM using 25 steps of EM.
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Failed:
# SLDS K=9, D=9... Failed: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 8 is different from 9)
# No SLDS models fitted successfully.

# %%
# SLDS BIC landscape
if slds_results:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    # BIC vs K for each D
    ax = axes[0]
    for D in D_LATENT_RANGE:
        ks = [k for k in K_RANGE if (k, D) in slds_results]
        bics = [slds_results[(k, D)]['bic'] for k in ks]
        if ks:
            ax.plot(ks, bics, 'o-', label=f'D={D}')
    ax.set_xlabel('K (discrete states)')
    ax.set_ylabel('BIC (lower = better)')
    ax.set_title('SLDS: BIC vs K')
    ax.legend()

    # BIC vs D for each K
    ax = axes[1]
    for K in K_RANGE:
        ds = [d for d in D_LATENT_RANGE if (K, d) in slds_results]
        bics = [slds_results[(K, d)]['bic'] for d in ds]
        if ds:
            ax.plot(ds, bics, 'o-', label=f'K={K}')
    ax.set_xlabel('D (latent dimensions)')
    ax.set_ylabel('BIC (lower = better)')
    ax.set_title('SLDS: BIC vs D')
    ax.legend()

    plt.tight_layout()
    plt.show()

# %%
slds_results
# Out:
# {}

# %%
# SLDS state assignments and latent trajectories
if slds_results:
    K_slds = best_K_slds
    D_latent = best_D_slds
    slds_best = slds_results[(K_slds, D_latent)]['model']

    slds_labels = {}   # animal_id -> discrete state labels
    slds_latent = {}   # animal_id -> continuous latent trajectory

    for aid, (X_a, sess_idx) in animal_sequences.items():
        z, x = slds_best.most_likely_states(X_a)
        slds_labels[aid] = z
        slds_latent[aid] = x

    # Plot: discrete states + latent trajectory
    n_animals = len(animal_sequences)
    fig, axes = plt.subplots(n_animals, 2,
                              figsize=(16, 2.5 * n_animals))
    if n_animals == 1:
        axes = axes.reshape(1, -1)

    state_colours = plt.cm.Set2(np.linspace(0, 1, K_slds))

    for row, (aid, (X_a, sess_idx)) in enumerate(animal_sequences.items()):
        z = slds_labels[aid]
        x_lat = slds_latent[aid]

        # Discrete states
        ax = axes[row, 0]
        for k in range(K_slds):
            mask = z == k
            ax.scatter(sess_idx[mask], np.ones(mask.sum()) * 0.5,
                       c=[state_colours[k]], s=80, marker='s', label=f'S{k}')
        ax.set_ylabel(aid, fontsize=9, fontweight='bold')
        ax.set_yticks([])
        if row == 0:
            ax.legend(fontsize=7, ncol=K_slds)
            ax.set_title('Discrete states')

        # Latent dimensions
        ax = axes[row, 1]
        for d in range(D_latent):
            ax.plot(sess_idx, x_lat[:, d], '-', alpha=0.7, lw=1.2, label=f'z{d}')
        if row == 0:
            ax.legend(fontsize=7)
            ax.set_title('Continuous latent trajectory')
        ax.set_ylabel(aid, fontsize=8)

    axes[-1, 0].set_xlabel('Session')
    axes[-1, 1].set_xlabel('Session')
    fig.suptitle(f'SLDS: K={K_slds}, D={D_latent}',
                 fontsize=13, fontweight='bold')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 6. HMM vs SLDS Comparison

# %%
if hmm_scores and slds_results:
    # BIC comparison
    hmm_bic = hmm_scores[best_K_bic]['bic']
    slds_bic = slds_results[best_slds_key]['bic']
    delta_bic = hmm_bic - slds_bic
    winner = 'SLDS' if delta_bic > 0 else 'HMM'
    print(f'HMM  (K={best_K_bic}):           BIC={hmm_bic:.1f}  '
          f'(n_params={hmm_scores[best_K_bic]["n_params"]})')
    print(f'SLDS (K={best_K_slds}, D={best_D_slds}): BIC={slds_bic:.1f}  '
          f'(n_params={slds_results[best_slds_key]["n_params"]})')
    print(f'\nΔBIC = {delta_bic:.1f} in favour of {winner}')
    if abs(delta_bic) < 10:
        print('(ΔBIC < 10: weak evidence — consider using the simpler HMM)')

    # Transition agreement
    print('\nState transition agreement (HMM vs SLDS):')
    for aid in animal_sequences:
        if aid in hmm_labels and aid in slds_labels:
            h = hmm_labels[aid]
            s = slds_labels[aid]
            h_trans = np.where(np.diff(h) != 0)[0]
            s_trans = np.where(np.diff(s) != 0)[0]
            print(f'  {aid}: HMM transitions at sessions {h_trans}, '
                  f'SLDS at {s_trans}')

# %% [markdown]
# ## 7. Validation: Expert State Consistency
#
# The terminal expert state should look similar across animals,
# even if reached at different session numbers.

# %%
if hmm_scores:
    print('Terminal state consistency (last 5 sessions):')
    terminal_states = {}
    for aid, labels in hmm_labels.items():
        last_5 = labels[-5:]
        dominant = np.bincount(last_5, minlength=K_best).argmax()
        frac = np.mean(last_5 == dominant)
        terminal_states[aid] = {
            'dominant_state': dominant,
            'state_name': STATE_NAMES.get(dominant, f'S{dominant}'),
            'fraction': frac,
        }
        print(f'  {aid}: {STATE_NAMES.get(dominant, f"S{dominant}")} '
              f'({frac:.0%} of last 5 sessions)')

    terminal_dominant = [v['dominant_state'] for v in terminal_states.values()]
    if len(set(terminal_dominant)) == 1:
        print(f'\nAll animals end in the same state: '
              f'{STATE_NAMES.get(terminal_dominant[0])}')
    else:
        print(f'\nTerminal states differ across animals: '
              f'{set(STATE_NAMES.get(s, f"S{s}") for s in terminal_dominant)}')
# Out:
# Terminal state consistency (last 5 sessions):
#   SS01: Intermediate_2 (100% of last 5 sessions)
#   SS04: Expert (80% of last 5 sessions)
#   SS05: Expert (60% of last 5 sessions)
#   SS06: Intermediate_1 (60% of last 5 sessions)
#   SS07: Intermediate_1 (100% of last 5 sessions)
#   SS08: Intermediate_2 (60% of last 5 sessions)
#   SS09: Intermediate_3 (80% of last 5 sessions)
#   SS10: Learning (80% of last 5 sessions)
#   SS11: Intermediate_1 (100% of last 5 sessions)
#   SS12: Intermediate_1 (80% of last 5 sessions)
#   SS13: Intermediate_2 (80% of last 5 sessions)
#   SS14: Intermediate_3 (60% of last 5 sessions)
#   SS15: Expert (100% of last 5 sessions)
#   SS16: Intermediate_1 (100% of last 5 sessions)
#   SS17: Intermediate_0 (60% of last 5 sessions)
#   SS18: Expert (100% of last 5 sessions)
#   SS19: Intermediate_0 (100% of last 5 sessions)
#   SS20: Intermediate_1 (60% of last 5 sessions)
#   SS21: Expert (60% of last 5 sessions)
#   SS22: Intermediate_0 (60% of last 5 sessions)
#   SS23: Intermediate_1 (60% of last 5 sessions)
#
# Terminal states differ across animals: {'Intermediate_3', 'Learning', 'Intermediate_2', 'Intermediate_0', 'Expert', 'Intermediate_1'}

# %% [markdown]
# ## 8. Leave-One-Animal-Out Validation
#
# Does the shared state structure generalise across animals?
# Train HMM on N−1 animals, predict states for the held-out animal,
# and compare to the full-model states via adjusted Rand index.
#
# This tests whether the state definitions are robust enough to
# assign learning phases to new animals (e.g. during the opto
# experiment) without retraining.

# %%
from sklearn.metrics import adjusted_rand_score

if hmm_scores:
    K_loao = best_K_bic
    loao_results = []

    aid_list = list(animal_sequences.keys())
    print(f'LOAO validation: K={K_loao}, {len(aid_list)} animals\n')

    for held_out_idx, held_out_aid in enumerate(aid_list):
        # Train set: all animals except held-out
        train_seqs = [
            animal_sequences[aid][0]  # X_a
            for aid in aid_list if aid != held_out_aid
        ]

        # Fit HMM on training set
        loao_hmm = ssm.HMM(K_loao, D_obs, observations='gaussian')
        best_ll = -np.inf
        best_hmm = None
        for restart in range(min(5, N_HMM_RESTARTS)):
            try:
                trial_hmm = ssm.HMM(K_loao, D_obs, observations='gaussian')
                trial_hmm.fit(train_seqs, method='em', num_iters=200)
                ll = sum(trial_hmm.log_likelihood(s) for s in train_seqs)
                if ll > best_ll:
                    best_ll = ll
                    best_hmm = trial_hmm
            except Exception:
                continue

        if best_hmm is None:
            print(f'  {held_out_aid}: HMM training failed')
            continue

        # Predict states for held-out animal
        X_held = animal_sequences[held_out_aid][0]
        loao_states = best_hmm.most_likely_states(X_held)

        # Full-model states for comparison
        full_states = hmm_labels[held_out_aid]

        # Adjusted Rand index (invariant to label permutation)
        ari = adjusted_rand_score(full_states, loao_states)

        loao_results.append({
            'animal_id': held_out_aid,
            'ari': ari,
            'n_sessions': len(full_states),
        })
        print(f'  {held_out_aid}: ARI = {ari:.3f} ({len(full_states)} sessions)')

    if loao_results:
        loao_df = pd.DataFrame(loao_results)
        print(f'\nMean ARI: {loao_df["ari"].mean():.3f} \u00b1 {loao_df["ari"].std():.3f}')
        print(f'Range: [{loao_df["ari"].min():.3f}, {loao_df["ari"].max():.3f}]')

        fig, ax = plt.subplots(figsize=(6, 4))
        ax.bar(loao_df['animal_id'], loao_df['ari'], color='steelblue', alpha=0.7)
        ax.axhline(loao_df['ari'].mean(), color='black', ls='--', lw=0.8,
                   label=f'mean = {loao_df["ari"].mean():.3f}')
        ax.set_ylabel('Adjusted Rand Index')
        ax.set_xlabel('Held-out animal')
        ax.set_title('Leave-One-Animal-Out: State Assignment Consistency')
        ax.set_ylim(0, 1)
        ax.legend()
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()
else:
    print('No HMM results — skipping LOAO validation')
# Out:
# LOAO validation: K=6, 21 animals
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS01: ARI = 0.399 (49 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS04: ARI = 0.246 (76 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS05: ARI = 0.522 (56 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS06: ARI = 0.429 (61 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS07: ARI = 0.341 (59 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS08: ARI = 0.654 (60 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS09: ARI = 0.546 (50 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS10: ARI = 0.235 (40 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS11: ARI = 0.149 (51 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS12: ARI = 0.240 (13 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS13: ARI = 0.913 (50 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS14: ARI = 0.654 (14 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS15: ARI = 0.450 (14 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS16: ARI = 0.791 (15 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS17: ARI = 0.597 (10 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS18: ARI = 0.445 (15 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS19: ARI = 0.597 (10 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS20: ARI = 0.744 (15 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS21: ARI = 0.171 (15 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS22: ARI = 0.404 (13 sessions)
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   SS23: ARI = 0.366 (13 sessions)
#
# Mean ARI: 0.471 ± 0.209
# Range: [0.149, 0.913]

# %% [markdown]
# ## 9. SLDS States on Adaptation Trajectories
#
# Overlay the discovered states onto adaptation trajectories from
# notebook 4a. This is the central integration: which state is each
# animal in at each phase of adaptation?

# %%
# ── Load adaptation results from 4a ─────────────────────────────────────────
ADAPT_PATH = Path('../results/adaptation/adaptation_results.pkl')

adapt_data = None
if ADAPT_PATH.exists():
    with open(ADAPT_PATH, 'rb') as f:
        adapt_data = pickle.load(f)
    print(f'Loaded adaptation results: {len(adapt_data.get("per_animal", {}))} animals')
else:
    # Try to detect shifts directly from current data
    try:
        from analysis.adaptation import detect_all_manipulations
        adapt_data = {'per_animal': {}}
        for aid in animal_sequences:
            animal = experiment.get_animal(aid)
            manips = detect_all_manipulations(animal, stage=STAGE)
            if manips:
                shift_idx = manips[0]['session_idx']
                sessions = animal.get_sessions(stage=STAGE)
                adapt_data['per_animal'][aid] = {
                    'shift': manips[0],
                    'all_sessions': sessions,
                }
        if adapt_data['per_animal']:
            print(f'Detected shifts for {len(adapt_data["per_animal"])} animals')
        else:
            print('No shifts detected in current data')
            adapt_data = None
    except Exception as e:
        print(f'Could not detect shifts: {e}')
        adapt_data = None
# Out:
# Detected shifts for 9 animals

# %%
# ── Overlay states on adaptation trajectories ────────────────────────────────
if adapt_data and hmm_scores:
    state_cmap = plt.cm.Set2

    for aid, res in adapt_data['per_animal'].items():
        if aid not in hmm_labels:
            continue

        labels = hmm_labels[aid]
        shift_info = res['shift']
        shift_idx = shift_info['session_idx']
        all_sessions = res.get('all_sessions', [])

        if len(labels) != len(all_sessions):
            print(f'{aid}: label count mismatch ({len(labels)} vs {len(all_sessions)}), skipping')
            continue

        # Compute accuracy per session
        acc_vals = []
        for s in all_sessions:
            st = s.stats(['accuracy'])
            acc_vals.append(st.get('accuracy', np.nan))

        rel_sessions = np.arange(len(all_sessions)) - shift_idx

        fig, axes = plt.subplots(2, 1, figsize=(12, 5), sharex=True,
                                 gridspec_kw={'height_ratios': [3, 1]})

        ax = axes[0]
        ax.plot(rel_sessions, acc_vals, 'o-', ms=4, color='grey', alpha=0.6)
        ax.axvline(0, color='black', ls=':', lw=0.8, label='Shift')
        ax.set_ylabel('Accuracy')
        shift_label = (
            f"{shift_info.get('details', {}).get('before', '?')} \u2192 "
            f"{shift_info.get('details', {}).get('after', '?')}"
        )
        ax.set_title(f'{aid}: {shift_label}')
        ax.legend(fontsize=8)

        ax2 = axes[1]
        K = labels.max() + 1
        for j in range(len(labels)):
            ax2.axvspan(rel_sessions[j] - 0.5, rel_sessions[j] + 0.5,
                        color=state_cmap(labels[j] / max(K - 1, 1)),
                        alpha=0.7)
        ax2.axvline(0, color='black', ls=':', lw=0.8)
        ax2.set_yticks([])
        ax2.set_ylabel('State')
        ax2.set_xlabel('Sessions relative to shift')

        # Add state legend
        for k in range(K):
            name = STATE_NAMES.get(k, f'State {k}') if 'STATE_NAMES' in dir() else f'State {k}'
            ax2.plot([], [], 's', color=state_cmap(k / max(K - 1, 1)),
                     ms=10, label=name)
        ax2.legend(fontsize=7, loc='upper right', ncol=K)

        plt.tight_layout()
        plt.show()
else:
    if not adapt_data:
        print('No adaptation data — run notebook 4a first (or no shifts in data)')
    if not hmm_scores:
        print('No HMM results available')
# Out:
# SS01: label count mismatch (49 vs 70), skipping
# SS04: label count mismatch (76 vs 77), skipping
# SS05: label count mismatch (56 vs 61), skipping
# SS07: label count mismatch (59 vs 61), skipping
# SS08: label count mismatch (60 vs 61), skipping
# SS09: label count mismatch (50 vs 52), skipping
# SS11: label count mismatch (51 vs 52), skipping
# SS13: label count mismatch (50 vs 52), skipping

# %% [markdown]
# ## 10. Online State Prediction
#
# Given the trained HMM/SLDS, predict the current state from a new
# session's features. This is the real-time trigger for Aim 2.

# %%
def predict_state(session, model, scaler, features, model_type='hmm'):
    """Predict state for a single new session.
    
    Args:
        session: SessionData object
        model: trained ssm HMM or SLDS model
        scaler: fitted StandardScaler
        features: list of feature names
        model_type: 'hmm' or 'slds'
    
    Returns:
        (state_label, info_dict) or (None, None) if NaN features
    """
    stats = session.stats(features)
    x = np.array([stats.get(f, np.nan) for f in features]).reshape(1, -1)
    if np.any(np.isnan(x)):
        return None, None
    x_std = scaler.transform(x)
    
    if model_type == 'hmm':
        state = model.most_likely_states(x_std)[0]
        return state, {}
    elif model_type == 'slds':
        z, x_lat = model.most_likely_states(x_std)
        return z[0], {'latent': x_lat[0]}
    else:
        raise ValueError(f'Unknown model_type: {model_type}')


# Demo: predict state for each session of one animal
if hmm_scores:
    demo_animal = all_animals[0]
    print(f'Online prediction demo: {demo_animal.animal_id}')
    sessions = demo_animal.get_sessions(stage=STAGE)

    for sess in sessions[-5:]:
        state, info = predict_state(sess, hmm_best, scaler, FEATURES, 'hmm')
        name = STATE_NAMES.get(state, f'S{state}') if state is not None else '?'
        acc = sess.stats(['accuracy']).get('accuracy', np.nan)
        print(f'  Session {sess.session_idx}: {name} (acc={acc:.2f})')
# Out:
# Online prediction demo: SS01
#   Session 69: ? (acc=0.45)
#   Session 70: ? (acc=0.48)
#   Session 71: ? (acc=0.45)
#   Session 72: ? (acc=0.52)
#   Session 73: Intermediate_2 (acc=0.51)

# %% [markdown]
# ## 11. Save Results

# %%
import pickle

results_dir = Path('../results/slds')
results_dir.mkdir(parents=True, exist_ok=True)

results = {
    'features': FEATURES,
    'scaler_mean': scaler.mean_,
    'scaler_scale': scaler.scale_,
    # HMM
    'hmm_K_best': best_K_bic if hmm_scores else None,
    'hmm_state_names': STATE_NAMES if hmm_scores else {},
    'hmm_labels': hmm_labels if hmm_scores else {},
    'hmm_state_means': means_df if hmm_scores else None,
    'hmm_bic_scores': {k: v['bic'] for k, v in hmm_scores.items()} if hmm_scores else {},
}

if slds_results:
    results['slds_K_best'] = best_K_slds
    results['slds_D_best'] = best_D_slds
    results['slds_labels'] = slds_labels
    results['slds_latent'] = slds_latent
    results['slds_bic_scores'] = {str(k): v['bic'] for k, v in slds_results.items()}

# Save models separately (they can be large)
if hmm_scores:
    results['hmm_model'] = hmm_best
if slds_results:
    results['slds_model'] = slds_best

with open(results_dir / 'slds_results.pkl', 'wb') as f:
    pickle.dump(results, f)
print(f'Saved to {results_dir / "slds_results.pkl"}')
# Out:
# Saved to ../results/slds/slds_results.pkl

# %% [markdown]
# ## Interpretation & Next Steps
#
# **If HMM finds clean Learning → Expert transition:**
# The transition session is the natural trigger for opto experiments.
# Animals that reach Expert state for N consecutive sessions are ready
# for distribution shift.
#
# **If SLDS adds value over HMM (ΔBIC > 10):**
# The continuous latent trajectory captures gradual within-state changes
# that HMM misses. This is particularly valuable for the post-shift
# re-learning trajectory.
#
# **If ΔBIC < 10 (weak preference):**
# Prefer the simpler HMM for online state prediction — fewer parameters,
# more robust to noise, and the discrete-only representation is sufficient
# for triggering opto.
#
# **If states don't separate cleanly:**
# May need more features, or a different feature set. The features from
# 1a were selected on pre-shift data — post-shift data may require
# different features.
#
# **Online application (Aim 2):**
# Train on the Aim 1 cohort → apply `predict_state()` in real-time
# to new animals → trigger opto when Expert state is stable.
#
# **Connection to model-based measures:**
# Compare SLDS states with η from SBI (notebook 3b). If SLDS "Learning"
# states have higher η than "Expert" states, model-free and model-based
# characterisations converge.
#
# **Note on SLDS log-likelihood approximation:**
# `ssm`'s `model.log_likelihood()` uses a Laplace approximation for the
# continuous latent states. This is standard practice and the approximation
# error is consistent across model configurations, so relative BIC
# comparisons are valid even if absolute LL values are approximate.
