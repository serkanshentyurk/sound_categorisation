# %% [markdown]
# Config for result path (validation or real etc)

# %% [markdown]
# look at the group assignment

# %% [markdown]
# basic fit related plots

# %% [markdown]
# pick an animal and look into behaviour
