# %% [markdown]
# load the conditioned results

# %% [markdown]
# select paths for the specific conditioned network

# %% [markdown]
# load the conditioned results

# %% [markdown]
# basic fit eval/stats

# %% [markdown]
# pick an animal

# %% [markdown]
# animal results
