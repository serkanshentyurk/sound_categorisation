# %% [markdown]
# loads the network and does the conditioning. technically i will do this on the cluster btu to show how it is done

# %% [markdown]
# load network

# %% [markdown]
# load animals

# %% [markdown]
# condition the network

# %% [markdown]
# save the results
