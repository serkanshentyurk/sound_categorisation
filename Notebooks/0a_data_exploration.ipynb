# %% [markdown]
# # 0a. Data Exploration & Pipeline Overview
#
# **Purpose:** Full data loading → summary statistics → visualisation pipeline.
#
# **Covers:**
# 1. Loading data (real CSVs, saved pkl, or synthetic)
# 2. Data class hierarchy inspection
# 3. Session-level summaries and feature matrix
# 4. Psychometric curves
# 5. Stat trajectories across sessions
# 6. Update matrices and serial dependence profiles
# 7. Manipulation detection and shift-aligned analysis

# %%
# %matplotlib inline

import os, sys
sys.path.append(os.path.abspath(".."))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# behav_utils — data
from behav_utils.data.structures import ExperimentData, AnimalData, SessionData
from behav_utils.data.synthetic import (
    generate_synthetic_animal,
    generate_synthetic_session,
    noisy_psychometric_simulator,
    sample_stimuli,
)
from behav_utils.data.loading import load_experiment, load_from_directory

# behav_utils — analysis
from behav_utils.analysis.summary_stats import (
    compute_summary_stats,
    list_available_stats,
    FEATURE_MATRIX_STATS,
    DEFAULT_STATS,
)
from behav_utils.analysis.session_features import (
    build_feature_matrix,
    build_feature_matrix_multi,
    summarise_features,
)
from behav_utils.analysis.update_matrix import compute_update_matrix
from behav_utils.analysis.utils import cumulative_gaussian

# behav_utils — plotting
from behav_utils.plotting.psychometric import (
    plot_psychometric,
    plot_session_psychometrics,
)
from behav_utils.plotting.trajectory import (
    plot_stat_trajectory,
    plot_multi_animal_trajectory,
    plot_stat_grid,
)
from behav_utils.plotting.update_matrix import (
    plot_update_matrix,
    plot_conditional_psychometrics,
)

print("All imports OK.")
print(f"Available summary statistics ({len(list_available_stats())}):")
for s in list_available_stats():
    print(f"  - {s}")
# Out:
# All imports OK.
# Available summary statistics (24):
#   - accuracy
#   - psychometric
#   - recency
#   - win_stay
#   - win_stay_rate
#   - lose_shift
#   - choice_autocorr
#   - side_bias
#   - stimulus_sensitivity
#   - choice_entropy
#   - perseveration
#   - logistic_history
#   - hard_easy_ratio
#   - hard_accuracy
#   - easy_accuracy
#   - conditional_psychometric
#   - update_matrix
#   - psychometric_gof
#   - stimulus_recency
#   - recency_divergence
#   - history_interaction_r2
#   - sd_profile
#   - binned_accuracy
#   - binned_choice_prob

# %% [markdown]
# ---
# ## 1. Load Data
#
# Three options — uncomment the one you need.
#
# **Option A:** `load_experiment('config.yaml')` — reads CSVs from disk using your config.
# **Option B:** `ExperimentData.load('experiment.pkl')` — reload from a saved pickle.
# **Option C:** Generate synthetic data (default for pipeline testing).

# %% [markdown]
# ### Option A
# `load_experiment('config.yaml')` — reads CSVs from disk using your config.

# %%
# ═══════════════════════════════════════════════════════════════════════════
# OPTION A: Load from CSV files
# ═══════════════════════════════════════════════════════════════════════════

path_config = '/Users/Serkan/Desktop/pro/PhD/main/repos/sound_categorisation/config.yaml'
experiment = load_experiment(path_config)
STAGE = 'Full_Task_Cont'
SHIFT_SESSION = None

# # Or point directly at a data directory:
# data_path = ''
# experiment = load_from_directory(data_path, config_path=path_config)

# # Load a single animal:
# from behav_utils.data.loading import load_animal
# from behav_utils.config.schema import load_config
# config = load_config(config_path)
# animal_path = ''
# animal = load_animal(animal_path, config)
# Out:
# Loaded 12 animals, 433 total sessions

# %% [markdown]
# ### Option B
# `ExperimentData.load('experiment.pkl')` — reload from a saved pickle.

# %%
# ═══════════════════════════════════════════════════════════════════════════
# OPTION B: Load from saved pickle
# ═══════════════════════════════════════════════════════════════════════════
# experiment = ExperimentData.load('experiment.pkl')
# animal = AnimalData.load('SS05.pkl')

# %% [markdown]
# ### Option C
# Generate synthetic data (default for pipeline testing).

# %%
# ═══════════════════════════════════════════════════════════════════════════
# OPTION C: Generate synthetic data (default)
# ═══════════════════════════════════════════════════════════════════════════
USE_SYNTHETIC = False

if USE_SYNTHETIC:
    def _learning_simulator(stimuli, categories, rng, sigma=0.3, lapse=0.05, **kw):
        from scipy.stats import norm
        p_b = lapse + (1 - 2 * lapse) * norm.cdf(stimuli, 0, sigma)
        return (rng.random(len(stimuli)) < p_b).astype(float)

    def generate_cohort(n_animals=5, n_sessions=25, shift_session=15, seed=42):
        rng = np.random.default_rng(seed)
        experiment = ExperimentData(metadata={'cohort': 'synthetic_demo'})
        for a in range(n_animals):
            animal_id = f'SYN{a+1:02d}'
            animal_seed = int(rng.integers(0, 2**31))
            rate = 0.1 + rng.uniform(-0.03, 0.03)
            sigmas = [max(0.12, 0.6 * np.exp(-rate * s)) for s in range(n_sessions)]
            lapses = [max(0.02, 0.15 * np.exp(-0.12 * s)) for s in range(n_sessions)]
            per_session_kwargs = [{'sigma': sigmas[s], 'lapse': lapses[s]}
                                  for s in range(n_sessions)]
            dist_schedule = (['uniform'] * shift_session
                             + ['exponential_left'] * (n_sessions - shift_session))
            animal, _ = generate_synthetic_animal(
                animal_id=animal_id, n_sessions=n_sessions, trials_per_session=300,
                seed=animal_seed, simulator=_learning_simulator,
                per_session_simulator_kwargs=per_session_kwargs,
                distribution_schedule=dist_schedule, stage='Full_Task_Cont',
            )
            experiment.add_animal(animal)
        return experiment

    experiment = generate_cohort()
    SHIFT_SESSION = 15
    STAGE = 'Full_Task_Cont'
    print(f"Generated synthetic cohort: {experiment.n_animals} animals, {experiment.animal_ids}")
else:
    SHIFT_SESSION = None
    STAGE = 'Full_Task_Cont'
    print(f"Loaded: {experiment.n_animals} animals, {experiment.animal_ids}")
# Out:
# Loaded: 12 animals, ['SS01', 'SS02', 'SS04', 'SS05', 'SS06', 'SS07', 'SS08', 'SS09', 'SS10', 'SS11', 'SS12', 'SS13']

# %% [markdown]
# ---
# ## 2. Data Hierarchy
#
# ```
# ExperimentData
# └── AnimalData  (one per mouse)
#     └── SessionData  (one per day)
#         ├── SessionMetadata  (stage, contingency, stim range, ...)
#         └── TrialData  (stimulus, choice, outcome, RT, opto, ...)
# ```

# %%
# Experiment
print("=== Experiment Summary ===")
print(experiment.summary().to_string(index=False))
print()

# Animal
animal = experiment.get_animal(experiment.animal_ids[0])
print(f"=== Animal: {animal.animal_id} ===")
print(f"  Sessions: {animal.n_sessions}, Stages: {animal.stages}")
print(f"  Dates: {animal.sessions[0].date} → {animal.sessions[-1].date}")
print()

# Session
session = animal.sessions[-1]
print(f"=== Session: {session.session_id} ===")
print(f"  Stage: {session.stage}, Distribution: {session.distribution}")
print(f"  Trials: {session.n_trials} total, {session.trials.valid_mask.sum()} valid, "
      f"{session.trials.abort.sum()} abort")

# Trial-level
trials = session.trials
print(f"\n=== TrialData ===")
print(f"  stimulus: [{trials.stimulus.min():.2f}, {trials.stimulus.max():.2f}]")
print(f"  choice unique: {np.unique(trials.choice[~np.isnan(trials.choice)])}")
print(f"  opto_on: {trials.opto_on.sum()} trials")
# Out:
# === Experiment Summary ===
# animal_id  n_sessions                           stages date_first  date_last
#      SS01          51 [Full_Task_Disc, Full_Task_Cont] 2026-01-05 2026-03-25
#      SS02          14 [Full_Task_Disc, Full_Task_Cont] 2025-12-02 2026-01-15
#      SS04          63 [Full_Task_Disc, Full_Task_Cont] 2025-12-01 2026-03-25
#      SS05          41                 [Full_Task_Cont] 2026-01-25 2026-03-25
#      SS06          41                 [Full_Task_Cont] 2026-01-25 2026-03-25
#      SS07          41                 [Full_Task_Cont] 2026-01-25 2026-03-25
#      SS08          41                 [Full_Task_Cont] 2026-01-25 2026-03-25
#      SS09          32                 [Full_Task_Cont] 2026-02-03 2026-03-25
#      SS10          32                 [Full_Task_Cont] 2026-02-03 2026-03-25
#      SS11          32                 [Full_Task_Cont] 2026-02-03 2026-03-25
#      SS12          13                 [Full_Task_Cont] 2026-02-03 2026-02-19
#      SS13          32                 [Full_Task_Cont] 2026-02-03 2026-03-25
#
# === Animal: SS01 ===
#   Sessions: 51, Stages: ['Full_Task_Disc', 'Full_Task_Cont']
#   Dates: 2026-01-05 → 2026-03-25
#
# === Session: SOUND_CAT_SS01_2026_3_25 ===
#   Stage: Full_Task_Cont, Distribution: Hard-B
#   Trials: 444 total, 444 valid, 0 abort
#
# === TrialData ===
#   stimulus: [-0.99, 1.00]
#   choice unique: [0. 1.]
#   opto_on: 0 trials

# %% [markdown]
# ## 3. Session-Level Summaries

# %%
# Experiment-level overview
fig, axes = experiment.plot_overview(
    animals='all', sessions=[-1,-2,-3], stage='Full_Task_Cont',
    stats=['accuracy', 'pse', 'recency', 'choice_entropy'],
)

# %%
rows = [s.summary() for s in animal.sessions]
session_df = pd.DataFrame(rows)
session_df['perf'] = session_df['perf'].round(3)
print(f"Sessions for {animal.animal_id}:")
print(session_df[['session_id', 'session_idx', 'date', 'stage',
                   'distribution', 'n_trials', 'n_valid', 'perf']].to_string(index=False))
# Out:
# Sessions for SS01:
#               session_id  session_idx       date          stage distribution  n_trials  n_valid  perf
#  SOUND_CAT_SS01_2026_1_5            0 2026-01-05 Full_Task_Disc      Uniform       420      399 0.757
# SOUND_CAT_SS01_2026_1_12            1 2026-01-12 Full_Task_Cont      Uniform       594      556 0.624
# SOUND_CAT_SS01_2026_1_13            2 2026-01-13 Full_Task_Cont      Uniform       399      388 0.647
# SOUND_CAT_SS01_2026_1_14            3 2026-01-14 Full_Task_Cont      Uniform       454      430 0.595
# SOUND_CAT_SS01_2026_1_15            4 2026-01-15 Full_Task_Cont      Uniform       476      462 0.671
# SOUND_CAT_SS01_2026_1_16            5 2026-01-16 Full_Task_Cont      Uniform       395      371 0.739
# SOUND_CAT_SS01_2026_1_17            6 2026-01-17 Full_Task_Cont      Uniform       389      360 0.669
# SOUND_CAT_SS01_2026_1_22            7 2026-01-22 Full_Task_Cont      Uniform       383      364 0.613
# SOUND_CAT_SS01_2026_1_23            8 2026-01-23 Full_Task_Cont      Uniform       417      404 0.658
# SOUND_CAT_SS01_2026_1_24            9 2026-01-24 Full_Task_Cont      Uniform       427      417 0.621
# SOUND_CAT_SS01_2026_1_25           10 2026-01-25 Full_Task_Cont      Uniform       317      308 0.539
# SOUND_CAT_SS01_2026_1_26           11 2026-01-26 Full_Task_Cont      Uniform       517      496 0.730
# SOUND_CAT_SS01_2026_1_27           12 2026-01-27 Full_Task_Cont      Uniform       573      553 0.644
# SOUND_CAT_SS01_2026_1_28           13 2026-01-28 Full_Task_Cont      Uniform       451      433 0.568
# SOUND_CAT_SS01_2026_1_29           14 2026-01-29 Full_Task_Cont      Uniform       626      606 0.685
# SOUND_CAT_SS01_2026_1_30           15 2026-01-30 Full_Task_Cont      Uniform       256      218 0.541
# SOUND_CAT_SS01_2026_1_31           16 2026-01-31 Full_Task_Cont      Uniform       410      382 0.599
#  SOUND_CAT_SS01_2026_2_1           17 2026-02-01 Full_Task_Cont      Uniform       316      316 0.522
#  SOUND_CAT_SS01_2026_2_2           18 2026-02-02 Full_Task_Cont      Uniform       353      352 0.659
#  SOUND_CAT_SS01_2026_2_3           19 2026-02-03 Full_Task_Cont      Uniform       535      516 0.610
#  SOUND_CAT_SS01_2026_2_5           20 2026-02-05 Full_Task_Cont      Uniform       645      645 0.598
#  SOUND_CAT_SS01_2026_2_7           21 2026-02-07 Full_Task_Cont      Uniform       693      664 0.705
#  SOUND_CAT_SS01_2026_2_8           22 2026-02-08 Full_Task_Cont      Uniform       541      525 0.651
#  SOUND_CAT_SS01_2026_2_9           23 2026-02-09 Full_Task_Cont      Uniform       682      662 0.713
# SOUND_CAT_SS01_2026_2_10           24 2026-02-10 Full_Task_Cont      Uniform       493      493 0.604
# SOUND_CAT_SS01_2026_2_11           25 2026-02-11 Full_Task_Cont      Uniform       682      680 0.640
# SOUND_CAT_SS01_2026_2_12           26 2026-02-12 Full_Task_Cont      Uniform       541      525 0.676
# SOUND_CAT_SS01_2026_2_13           27 2026-02-13 Full_Task_Cont      Uniform       499      499 0.685
# SOUND_CAT_SS01_2026_2_16           28 2026-02-16 Full_Task_Cont      Uniform       500      500 0.762
# SOUND_CAT_SS01_2026_2_17           29 2026-02-17 Full_Task_Cont      Uniform       623      601 0.705
# SOUND_CAT_SS01_2026_2_18           30 2026-02-18 Full_Task_Cont      Uniform       733      731 0.633
# SOUND_CAT_SS01_2026_2_19           31 2026-02-19 Full_Task_Cont      Uniform       647      633 0.630
# SOUND_CAT_SS01_2026_2_20           32 2026-02-20 Full_Task_Cont      Uniform       539      520 0.642
# SOUND_CAT_SS01_2026_2_21           33 2026-02-21 Full_Task_Cont      Uniform       493      487 0.704
# SOUND_CAT_SS01_2026_2_23           34 2026-02-23 Full_Task_Cont      Uniform       647      641 0.741
# SOUND_CAT_SS01_2026_2_24           35 2026-02-24 Full_Task_Cont      Uniform       623      622 0.683
#  SOUND_CAT_SS01_2026_3_3           36 2026-03-03 Full_Task_Cont      Uniform       563      530 0.670
#  SOUND_CAT_SS01_2026_3_4           37 2026-03-04 Full_Task_Cont      Uniform       516      495 0.731
#  SOUND_CAT_SS01_2026_3_5           38 2026-03-05 Full_Task_Cont      Uniform       598      598 0.712
#  SOUND_CAT_SS01_2026_3_6           39 2026-03-06 Full_Task_Cont      Uniform       368      352 0.741
#  SOUND_CAT_SS01_2026_3_9           40 2026-03-09 Full_Task_Cont      Uniform       670      660 0.688
# SOUND_CAT_SS01_2026_3_10           41 2026-03-10 Full_Task_Cont      Uniform       371      347 0.741
# SOUND_CAT_SS01_2026_3_11           42 2026-03-11 Full_Task_Cont      Uniform       408      390 0.731
# SOUND_CAT_SS01_2026_3_13           43 2026-03-13 Full_Task_Cont      Uniform       322      301 0.718
# SOUND_CAT_SS01_2026_3_16           44 2026-03-16 Full_Task_Cont       Hard-B       431      427 0.593
# SOUND_CAT_SS01_2026_3_17           45 2026-03-17 Full_Task_Cont       Hard-B       389      369 0.593
# SOUND_CAT_SS01_2026_3_18           46 2026-03-18 Full_Task_Cont       Hard-B       477      458 0.546
# SOUND_CAT_SS01_2026_3_20           47 2026-03-20 Full_Task_Cont       Hard-B       431      422 0.524
# SOUND_CAT_SS01_2026_3_23           48 2026-03-23 Full_Task_Cont       Hard-B       466      449 0.557
# SOUND_CAT_SS01_2026_3_24           49 2026-03-24 Full_Task_Cont       Hard-B       408      407 0.555
# SOUND_CAT_SS01_2026_3_25           50 2026-03-25 Full_Task_Cont       Hard-B       444      444 0.565

# %%
# Animal-level overview
animal = experiment.get_animal(experiment.animal_ids[0])
fig, axes = animal.plot_overview(sessions='last_5', stage='Full_Task_Cont')

# %%
# Per-animal psychometric subplots
fig, axes, infos = experiment.plot_psychometric(
    mode='per_animal', sessions='last_5', sub_mode='session_mean', show_ci=True
)

# %%
# Pooled with individual sessions visible
fig, ax, info = animal.plot_psychometric(
    mode='pooled', 
    sessions='last_5',
    show_individual=True, n_bootstrap=200, show_ci=True, show_gof = True
)

# %%
# Custom subplot titles in grid
fig, axes, infos = animal.plot_psychometric(
    mode='grid', sessions=[0, 5, 10, 25, 31],
    subplot_titles=['Naive', 'Early', 'Mid', 'Late', 'Expert'],
)

# %%
# Pooled with individual sessions visible
animal = experiment.get_animal(experiment.animal_ids[7])
fig, ax, info = animal.plot_psychometric_compare(
    groups={'Uniform': [-10, -9, -8, -7, -6], 'Hard-B': 'last_5'},
    mode='pooled',
    show_individual=True,
    n_bootstrap=200,
    show_gof=True,           
)

# %% [markdown]
# ## 4. Summary Statistics
#
# **DEFAULT_STATS** (SBI): accuracy, psychometric, recency, win_stay, stimulus_sensitivity
# **FEATURE_MATRIX_STATS** (SLDS/feature matrix): full set including entropy, perseveration, update matrix, etc.

# %%
session_early = animal.sessions[3]
session_late = animal.sessions[-1]

early_s = session_early.stats(stat_names=['accuracy', 'psychometric', 'recency'])
late_s = session_late.stats(stat_names=['accuracy', 'psychometric', 'recency'])

header = f"{'Metric':<20} {'Early (S1)':<15} {'Late (S' + str(session_late.session_idx) + ')':<15}"
print(header)
print("-" * len(header))
print(f"{'accuracy':<20} {early_s['accuracy']:<15.3f} {late_s['accuracy']:<15.3f}")
for key in ['pse', 'slope', 'lapse_low', 'lapse_high']:
    ev = early_s['psychometric'].get(key, np.nan)
    lv = late_s['psychometric'].get(key, np.nan)
    print(f"{key:<20} {f'{ev:.3f}':<15} {f'{lv:.3f}':<15}")
print(f"{'recency':<20} {early_s['recency']:<15.3f} {late_s['recency']:<15.3f}")
# Out:
# Metric               Early (S1)      Late (S31)
# ----------------------------------------------------
# accuracy             0.583           0.745
# pse                  0.816           0.031
# slope                1.397           0.220
# lapse_low            0.325           0.232
# lapse_high           0.000           0.112
# recency              0.340           0.183

# %% [markdown]
# ## 5. Psychometric Curves

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4))
for ax, (idx, label) in zip(axes, [(1, 'naive'), (10, 'learning'), (-1, 'expert/post-shift')]):
    s = animal.sessions[idx]
    arrays = s.trials.get_arrays()
    valid = ~arrays['no_response']
    plot_psychometric(arrays['stimuli'][valid], arrays['choices'][valid],
                      ax=ax, title=f'{s.session_id} ({label})')
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
plot_session_psychometrics(animal.sessions[:5], mode='overlay', ax=axes[0])
axes[0].set_title('First 5 sessions')
plot_session_psychometrics(animal.sessions[-5:], mode='overlay', ax=axes[1])
axes[1].set_title('Last 5 sessions')
plt.tight_layout()
plt.show()

# %%
fig, ax, info = animal.plot_psychometric(mode='pooled', # pooled, session_mean
                                         show_individual=True, 
                                         individual_alpha=0.15, 
                                         n_bootstrap=100,
                                         show_ci=False,
                                         show_gof=True)

# %%
# Mean psychometric with SEM from between-session variability
fig, ax, info = plot_session_psychometrics(
    animal.sessions[-5:], 
    mode='pooled',
    show_individual=True,     # faint per-session curves underneath
    individual_alpha=0.15,
    show_ci=True,             # SEM band on mean curve
    n_bootstrap=100,
    show_gof=True             # display goodness-of-fit info
)

# %%
# Mean psychometric with SEM from between-session variability
fig, ax, info = plot_session_psychometrics(
    animal.sessions[-5:], 
    mode='session_mean',
    show_individual=True,     # faint per-session curves underneath
    individual_alpha=0.15,
    show_ci=True,             # SEM band on mean curve
    show_gof=True             # display goodness-of-fit info
)

# %% [markdown]
# ## 6. Feature Matrix

# %%
df = build_feature_matrix(animal, stage=STAGE)
print(f"Feature matrix: {df.shape[0]} sessions × {df.shape[1]} columns")
print(f"\nColumns ({len(df.columns)}):")
for col in sorted(df.columns):
    print(f"  {col}")
# Out:
# Feature matrix: 32 sessions × 151 columns
#
# Columns (151):
#   abort_rate
#   accuracy
#   animal_id
#   choice_autocorr
#   choice_entropy
#   cond_lapse_high_0
#   cond_lapse_high_1
#   cond_lapse_high_2
#   cond_lapse_high_3
#   cond_lapse_high_4
#   cond_lapse_high_5
#   cond_lapse_high_6
#   cond_lapse_high_7
#   cond_lapse_low_0
#   cond_lapse_low_1
#   cond_lapse_low_2
#   cond_lapse_low_3
#   cond_lapse_low_4
#   cond_lapse_low_5
#   cond_lapse_low_6
#   cond_lapse_low_7
#   cond_pse_0
#   cond_pse_1
#   cond_pse_2
#   cond_pse_3
#   cond_pse_4
#   cond_pse_5
#   cond_pse_6
#   cond_pse_7
#   cond_slope_0
#   cond_slope_1
#   cond_slope_2
#   cond_slope_3
#   cond_slope_4
#   cond_slope_5
#   cond_slope_6
#   cond_slope_7
#   date
#   delta_accuracy
#   delta_choice_entropy
#   delta_pse
#   delta_recency
#   delta_rt_median
#   delta_side_bias
#   delta_slope
#   distribution
#   easy_accuracy
#   hard_accuracy
#   hard_easy_ratio
#   history_decay
#   history_interaction_r2
#   lapse_high
#   lapse_low
#   lose_shift
#   n_trials_abort
#   n_trials_total
#   n_trials_valid
#   perseveration
#   proportion_fast
#   pse
#   psychometric_gof
#   recency
#   recency_divergence
#   rt_correct_vs_error
#   rt_iqr
#   rt_median
#   rt_median_easy
#   rt_median_hard
#   rt_skewness
#   sd_curvature
#   sd_range
#   sd_slope
#   session_id
#   session_idx
#   side_bias
#   slope
#   stage
#   stimulus_recency
#   stimulus_sensitivity
#   um_0_0
#   um_0_1
#   um_0_2
#   um_0_3
#   um_0_4
#   um_0_5
#   um_0_6
#   um_0_7
#   um_1_0
#   um_1_1
#   um_1_2
#   um_1_3
#   um_1_4
#   um_1_5
#   um_1_6
#   um_1_7
#   um_2_0
#   um_2_1
#   um_2_2
#   um_2_3
#   um_2_4
#   um_2_5
#   um_2_6
#   um_2_7
#   um_3_0
#   um_3_1
#   um_3_2
#   um_3_3
#   um_3_4
#   um_3_5
#   um_3_6
#   um_3_7
#   um_4_0
#   um_4_1
#   um_4_2
#   um_4_3
#   um_4_4
#   um_4_5
#   um_4_6
#   um_4_7
#   um_5_0
#   um_5_1
#   um_5_2
#   um_5_3
#   um_5_4
#   um_5_5
#   um_5_6
#   um_5_7
#   um_6_0
#   um_6_1
#   um_6_2
#   um_6_3
#   um_6_4
#   um_6_5
#   um_6_6
#   um_6_7
#   um_7_0
#   um_7_1
#   um_7_2
#   um_7_3
#   um_7_4
#   um_7_5
#   um_7_6
#   um_7_7
#   w_prev_choice_1
#   w_prev_choice_2
#   w_prev_choice_3
#   w_prev_outcome_1
#   w_prev_outcome_2
#   w_prev_outcome_3
#   w_stimulus
#   win_stay

# %% [markdown]
# ## 7. Stat Trajectories
#
# Using `behav_utils.plotting.trajectory`: `plot_stat_trajectory` (single animal), `plot_multi_animal_trajectory` (group), `plot_stat_grid` (multi-panel grid).

# %%
# Single animal: one stat
fig, ax = animal.plot_trajectory('accuracy', stage=STAGE)
if SHIFT_SESSION is not None:
    ax.axvline(SHIFT_SESSION, color='red', linestyle='--', alpha=0.6, label='shift')
    ax.legend(fontsize=8)
plt.show()

# %%
# Out:
# 'SS09'

# %%
# Single animal: stat grid
stats_to_plot = ['accuracy', 'pse', 'slope', 'recency',
                 'side_bias', 'choice_entropy', 'win_stay', 'lapse_low']
stats_to_plot = [s for s in stats_to_plot if s in df.columns]

fig, axes = plot_stat_grid(
    [animal], stats=stats_to_plot, stage=STAGE,
    combine='none', show_individual=True
)
if SHIFT_SESSION is not None:
    for ax in axes.flatten():
        if ax.get_visible():
            ax.axvline(SHIFT_SESSION, color='red', linestyle='--', alpha=0.4)
plt.show()

# %%
# Multi-animal: mean ± SEM
all_animals = experiment.get_animals(min_sessions=5)

fig, axes = plot_stat_grid(
    all_animals, stats=stats_to_plot, stage=STAGE,
    combine='mean_sem', show_individual=True, individual_alpha=0.2,
)
if SHIFT_SESSION is not None:
    for ax in axes.flatten():
        if ax.get_visible():
            ax.axvline(SHIFT_SESSION, color='red', linestyle='--', alpha=0.4)
plt.show()

# %%
animal = experiment.get_animal(experiment.animal_ids[7])
print(f"Plotting psychometric and trajectory for animal {animal.animal_id}...")
fig, ax, info = animal.plot_psychometric(sessions = 'last_5',
                                          mode = 'session_mean',
                                          show_ci=True)

fig_ac, ax_ac = animal.plot_trajectory('accuracy', stage=STAGE)
# Out:
# Plotting psychometric and trajectory for animal SS09...

# %% [markdown]
# ---
# ## 8. Update Matrices & Serial Dependence
#
# The update matrix captures serial dependence: how does the previous trial's
# stimulus shift the current psychometric curve? This is the critical link
# between model predictions and actual behaviour.
#
# ### 8.1 Naive vs Expert

# %%
# Compare update matrix: early (naive) vs late (expert) session
sessions = animal.get_sessions(stage=STAGE)
EARLY_IDX = min(3, len(sessions) - 1)
LATE_IDX = len(sessions) - 1

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for col, (sidx, label) in enumerate([(EARLY_IDX, 'Naive'), (LATE_IDX, 'Expert')]):
    sess = sessions[sidx]
    arrays = sess.trials.get_arrays(exclude_abort=True, exclude_opto=True)
    valid = ~arrays['no_response']
    s, c, cat = arrays['stimuli'][valid], arrays['choices'][valid], arrays['categories'][valid]

    um, cond_mat, info = compute_update_matrix(s, c, cat, n_bins=8)
    plot_update_matrix(um, title=f'{label} (session {sidx})', ax=axes[col])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.2 Update matrix evolution across learning

# %%
# Compute update matrices at several points across learning
sessions = animal.get_sessions(stage=STAGE)
n_sess = len(sessions)
indices = np.linspace(2, n_sess - 1, min(5, n_sess), dtype=int)
indices = sorted(set(indices))

fig, axes = plt.subplots(1, len(indices), figsize=(3.5 * len(indices), 3.5))
if len(indices) == 1:
    axes = [axes]

# Compute all matrices first for consistent colour scale
ums = []
for sidx in indices:
    sess = sessions[sidx]
    arrays = sess.trials.get_arrays(exclude_abort=True, exclude_opto=True)
    valid = ~arrays['no_response']
    s, c, cat = arrays['stimuli'][valid], arrays['choices'][valid], arrays['categories'][valid]
    um, _, info = compute_update_matrix(s, c, cat, n_bins=8)
    ums.append(um)

vmax = max(np.nanmax(np.abs(um)) for um in ums if not np.all(np.isnan(um)))

for i, (sidx, um) in enumerate(zip(indices, ums)):
    plot_update_matrix(um, title=f'S{sidx}', ax=axes[i], vmin=-vmax, vmax=vmax)

fig.suptitle(f'{animal.animal_id}: Update matrix evolution', fontsize=12, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.3 Serial dependence profiles
#
# Overlay the column-mean of the update matrix (serial dependence profile) across sessions. As the animal learns, the profile should flatten (serial dependence diminishes).

# %%
fig, ax = plt.subplots(figsize=(7, 4))
cmap_sess = plt.cm.viridis

midpoints = np.linspace(-1, 1, 9)
midpoints = (midpoints[:-1] + midpoints[1:]) / 2

for i, (sidx, um) in enumerate(zip(indices, ums)):
    profile = np.nanmean(um, axis=0)
    frac = i / max(len(indices) - 1, 1)
    ax.plot(midpoints, profile, 'o-', color=cmap_sess(frac), lw=1.5, ms=5,
            label=f'S{sidx}', alpha=0.8)

ax.axhline(0, color='k', lw=0.5)
ax.set_xlabel('Previous stimulus bin')
ax.set_ylabel('Mean P(B) shift')
ax.set_title(f'{animal.animal_id}: Serial dependence profile evolution')
ax.legend(fontsize=8, ncol=2)
ax.grid(True, alpha=0.2)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/l1/l742y54d4hx05wj38054vs_r0000gn/T/ipykernel_84073/2968482086.py:8: RuntimeWarning: Mean of empty slice
#   profile = np.nanmean(um, axis=0)

# %% [markdown]
# ### 8.4 Conditional psychometric curves
#
# For an expert session, plot psychometric curves conditioned on the previous stimulus bin.

# %%
sess = sessions[-2]
arrays = sess.trials.get_arrays(exclude_abort=True, exclude_opto=True)
valid = ~arrays['no_response']
s, c, cat = arrays['stimuli'][valid], arrays['choices'][valid], arrays['categories'][valid]

um, cond_mat, info = compute_update_matrix(s, c, cat, n_bins=8)

fig, ax = plt.subplots(figsize=(7, 5))
x_fine = np.linspace(-1, 1, 200)
n_bins = 8
bin_edges = np.linspace(-1, 1, n_bins + 1)
midpoints = (bin_edges[:-1] + bin_edges[1:]) / 2
cmap = plt.cm.coolwarm

for b in range(n_bins):
    row = info['conditional_psychometrics'][b]
    if row is None or len(row) == 0:
        continue
    # row is a dict from compute_update_matrix with psychometric params per previous bin
    if isinstance(row, dict) and 'mu' in row and not np.isnan(row['mu']):
        y = cumulative_gaussian(x_fine, row['mu'], row['sigma'],
                                row.get('lapse_low', 0), row.get('lapse_high', 0))
        frac = b / (n_bins - 1)
        ax.plot(x_fine, y, color=cmap(frac), lw=1.5,
                label=f'Prev bin {midpoints[b]:.2f}', alpha=0.8)

ax.plot(info['total_psychometric']['x_fit'], info['total_psychometric']['y_fit'], 'k--', label='Overall psychometric')
ax.axvline(0, color='grey', lw=0.5, ls='--', alpha=0.3)
ax.axhline(0.5, color='grey', lw=0.5, ls='--', alpha=0.3)
ax.set_xlabel('Current stimulus')
ax.set_ylabel('P(choose B)')
ax.set_title(f'{sess.session_id}: Conditional psychometric curves')
ax.legend(fontsize=7, bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 9. Manipulation Detection & Shift-Aligned Analysis

# %%
from Analysis.adaptation import (
	detect_manipulation_session,
	detect_all_manipulations,
	align_animal,
	compute_convergence_metrics,
	compare_phases,
	classify_all_sessions,
)
ADAPTATION_AVAILABLE = True

# %%
for aid in experiment.animal_ids:
	a = experiment.get_animal(aid)
	manip = detect_manipulation_session(a, stage=STAGE)
	if manip:
		print(f"{aid}: {manip['type']} at session {manip['session_idx']}")
		print(f"  Details: {manip['details']}")
	else:
		print(f"{aid}: no manipulation detected")
# Out:
# SS01: distribution_shift at session 43
#   Details: {'before': 'Uniform', 'after': 'Hard-B'}
# SS02: no manipulation detected
# SS04: distribution_shift at session 50
#   Details: {'before': 'Uniform', 'after': 'Hard-B'}
# SS05: distribution_shift at session 34
#   Details: {'before': 'Uniform', 'after': 'Hard-B'}
# SS06: distribution_shift at session 34
#   Details: {'before': 'Uniform', 'after': 'Hard-B'}
# SS07: distribution_shift at session 34
#   Details: {'before': 'Uniform', 'after': 'Hard-B'}
# SS08: distribution_shift at session 34
#   Details: {'before': 'Uniform', 'after': 'Hard-B'}
# SS09: distribution_shift at session 25
#   Details: {'before': 'Uniform', 'after': 'Hard-B'}
# SS10: no manipulation detected
# SS11: distribution_shift at session 28
#   Details: {'before': 'Uniform', 'after': 'Hard-B'}
# SS12: no manipulation detected
# SS13: distribution_shift at session 27
#   Details: {'before': 'Uniform', 'after': 'Hard-B'}

# %%
animal = experiment.get_animal(experiment.animal_ids[7])
manip = detect_manipulation_session(animal, stage=STAGE)
if manip:
	aligned = align_animal(animal, manip['session_idx'], stage=STAGE)
	print(f"Aligned: {aligned.shape}, "
			f"pre={int((aligned['relative_session'] < 0).sum())}, "
			f"post={int((aligned['relative_session'] >= 0).sum())}")

	comparison = compare_phases(aligned)
	cols = [c for c in ['feature', 'pre_mean', 'early_post_mean',
			'wilcoxon_p', 'cliffs_delta', 'recovery_ratio'] if c in comparison.columns]
	print(f"\nPhase comparison ({animal.animal_id}):")
	print(comparison[cols].to_string(index=False))
# Out:
# Aligned: (32, 153), pre=25, post=7
#
# Phase comparison (SS09):
#          feature  pre_mean  early_post_mean  wilcoxon_p  cliffs_delta  recovery_ratio
#         accuracy  0.782011         0.734275      0.0625          0.68       -0.306150
#              pse  0.041573        -0.056218      0.6250          0.28       -0.373350
#          recency  0.131221         0.232500      0.1875         -0.76        0.013333
# stimulus_recency  0.131221         0.232500      0.1875         -0.76        0.013333
#   choice_entropy  0.664983         0.663503      1.0000          0.04        2.000000
#            slope  0.399356         0.286587      0.3125          0.52        0.111616
#        side_bias  0.003937         0.077318      0.1250         -0.36       -0.113609

# %%
if manip:
    convergence = compute_convergence_metrics(aligned)
    cols = [c for c in ['feature', 'exp_tau', 'exp_r_squared',
            'ttc_sessions_to_criterion'] if c in convergence.columns]
    print("Convergence metrics:")
    print(convergence[cols].to_string(index=False))
else:
    print("No manipulation detected, skipping convergence analysis.")
# Out:
# Convergence metrics:
#          feature    exp_tau  exp_r_squared  ttc_sessions_to_criterion
#         accuracy   0.854462       0.920475                        0.0
#              pse   2.043283       0.923733                        NaN
#          recency   1.271872       0.526277                        2.0
# stimulus_recency   1.271872       0.526277                        2.0
#   choice_entropy 100.000000       0.009199                        NaN
#            slope 100.000000       0.671546                        NaN
#        side_bias   0.464804       0.580568                        NaN

# %% [markdown]
# ---
# ## 10. Saving & Reloading
#
# ```python
# experiment.save('experiment.pkl')
# animal.save('SS05.pkl')
#
# # Reload:
# experiment = ExperimentData.load('experiment.pkl')
# animal = AnimalData.load('SS05.pkl')
# ```
